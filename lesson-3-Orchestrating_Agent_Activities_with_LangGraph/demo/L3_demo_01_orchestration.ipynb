# %% [markdown]
# ## 0. Setup

# %%
import os
from typing import Dict, Any
from dotenv import load_dotenv
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langgraph.graph.message import MessagesState
from langgraph.prebuilt import create_react_agent

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.0,
    base_url="https://openai.vocareum.com/v1",
    api_key=os.getenv("VOCAREUM_API_KEY")
)

# %% [markdown]
# ## 1. Sub Agents

# %%
research_worker = create_react_agent(
    name="research_worker",
    prompt=SystemMessage(
        content=(
            "You are a research specialist. Given a topic, find key information. "
            "Return ONLY JSON with: keywords, sources."
        )
    ),
    model=llm,
    tools=[],
)

# %%
type(research_worker)
# Out:
# langgraph.graph.state.CompiledStateGraph

# %%
research_worker

# %%
writing_worker = create_react_agent(
    name="writing_worker",
    prompt=SystemMessage(
        content=(
            "You are a content writer. " 
            "Given research keywords, write clear and concise content. "
            "Return ONLY JSON with: content, summary."
        )
    ),
    model=llm,
    tools=[],
)

# %% [markdown]
# ## 2. Handoff Tools

# %%
@tool
def call_researcher(topic: str) -> Dict[str, Any]:
    """Ask the research worker to find information about a topic."""
    message = HumanMessage(content=f"Research this topic: {topic}")
    
    result = research_worker.invoke(
        input={"messages": [message]}
    )
    
    last_message: AIMessage = result["messages"][-1]
    
    # Simple parsing (could use structured output for production)
    return {
        "task": "research",
        "topic": topic,
        "results": last_message.content
    }

# %%
@tool
def call_writer(research_keywords: str) -> Dict[str, Any]:
    """Ask the writing worker to create content based on research."""
    message = HumanMessage(
        content=f"Write a concise content based on these keywords: {research_keywords}"
    )
    
    result = writing_worker.invoke(
        input={"messages": [message]}
    )
    
    last_message:AIMessage = result["messages"][-1]
    
    return {
        "task": "writing",
        "research": research_keywords,
        "results": last_message.content
    }

# %% [markdown]
# ## 3. Orchestrator

# %%
supervisor_agent = create_react_agent(
    name="supervisor_agent",
    prompt=SystemMessage(
        content=(
            "You are a task supervisor. When given a request:\n"
            "1. First use research_topic to gather information\n"
            "2. Then use write_content to create content based on the research\n"
            "3. Combine everything into a final response\n\n"
            "Use the tools in this order: research_topic → write_content"
        )
    ),
    model=llm,
    tools=[call_researcher, call_writer],
)

# %% [markdown]
# ## 4. Run

# %%
result = supervisor_agent.invoke(
    input={
        "messages": [
            HumanMessage(
                content="topic machine learning basics"
            )
        ]
    }
)

# %%
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# topic machine learning basics
# ================================== Ai Message ==================================
# Name: supervisor_agent
# Tool Calls:
#   call_researcher (call_hiYjz4sKK1ffPm1Iou42OX3a)
#  Call ID: call_hiYjz4sKK1ffPm1Iou42OX3a
#   Args:
#     topic: machine learning basics
# ================================= Tool Message =================================
# Name: call_researcher
#
# {"task": "research", "topic": "machine learning basics", "results": "{\n  \"keywords\": [\n    \"machine learning\",\n    \"supervised learning\",\n    \"unsupervised learning\",\n    \"reinforcement learning\",\n    \"algorithms\",\n    \"data preprocessing\",\n    \"model training\",\n    \"overfitting\",\n    \"underfitting\",\n    \"neural networks\",\n    \"decision trees\",\n    \"support vector machines\",\n    \"feature selection\",\n    \"cross-validation\",\n    \"evaluation metrics\"\n  ],\n  \"sources\": [\n    \"https://www.coursera.org/learn/machine-learning\",\n    \"https://www.edx.org/course/machine-learning-introduction\",\n    \"https://www.kaggle.com/learn/overview\",\n    \"https://www.ibm.com/cloud/learn/machine-learning\",\n    \"https://towardsdatascience.com/machine-learning-basics-101-1f1c1c1e1f3e\",\n    \"https://www.analyticsvidhya.com/blog/2020/10/understanding-machine-learning-algorithms/\",\n    \"https://www.sciencedirect.com/topics/computer-science/machine-learning\",\n    \"https://www.geeksforgeeks.org/machine-learning-introduction/\"\n  ]\n}"}
# ================================== Ai Message ==================================
# Name: supervisor_agent
# Tool Calls:
#   call_writer (call_MNhKG66E7G3C8nQMRSRRniMB)
#  Call ID: call_MNhKG66E7G3C8nQMRSRRniMB
#   Args:
#     research_keywords: machine learning, supervised learning, unsupervised learning, reinforcement learning, algorithms, data preprocessing, model training, overfitting, underfitting, neural networks, decision trees, support vector machines, feature selection, cross-validation, evaluation metrics
# ================================= Tool Message =================================
# Name: call_writer
#
# {"task": "writing", "research": "machine learning, supervised learning, unsupervised learning, reinforcement learning, algorithms, data preprocessing, model training, overfitting, underfitting, neural networks, decision trees, support vector machines, feature selection, cross-validation, evaluation metrics", "results": "{\n  \"content\": \"Machine learning is a subset of artificial intelligence that enables systems to learn from data and improve over time. It is broadly categorized into three types: supervised learning, unsupervised learning, and reinforcement learning. Supervised learning involves training algorithms on labeled data, allowing models to predict outcomes based on input features. Common algorithms include decision trees, support vector machines, and neural networks. In contrast, unsupervised learning deals with unlabeled data, focusing on discovering patterns or groupings within the data. Reinforcement learning teaches models to make decisions through trial and error, optimizing for long-term rewards. Data preprocessing is crucial for preparing raw data for model training, involving steps like cleaning, normalization, and feature selection. During model training, it is essential to avoid overfitting (where a model learns noise in the training data) and underfitting (where a model fails to capture the underlying trend). Techniques like cross-validation help assess model performance and generalization. Evaluation metrics, such as accuracy, precision, recall, and F1 score, are used to measure the effectiveness of machine learning models.\",\n  \"summary\": \"Machine learning encompasses supervised, unsupervised, and reinforcement learning, utilizing algorithms like decision trees and neural networks. Key processes include data preprocessing, model training, and avoiding overfitting and underfitting. Cross-validation and evaluation metrics are essential for assessing model performance.\"\n}"}
# ================================== Ai Message ==================================
# Name: supervisor_agent
#
# ### Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn from data and improve over time. It is broadly categorized into three main types:
#
# 1. **Supervised Learning**: This involves training algorithms on labeled data, allowing models to predict outcomes based on input features. Common algorithms in this category include decision trees, support vector machines, and neural networks.
#
# 2. **Unsupervised Learning**: In contrast to supervised learning, unsupervised learning deals with unlabeled data. The focus here is on discovering patterns or groupings within the data without predefined labels.
#
# 3. **Reinforcement Learning**: This type teaches models to make decisions through trial and error, optimizing for long-term rewards. It is often used in scenarios where an agent interacts with an environment to achieve a goal.
#
# ### Key Concepts in Machine Learning
#
# - **Data Preprocessing**: This is crucial for preparing raw data for model training. It involves steps like cleaning, normalization, and feature selection to ensure the data is suitable for analysis.
#
# - **Model Training**: During this phase, algorithms learn from the training data. It is essential to avoid two common pitfalls:
#   - **Overfitting**: This occurs when a model learns noise in the training data, leading to poor generalization to new data.
#   - **Underfitting**: This happens when a model fails to capture the underlying trend of the data, resulting in poor performance.
#
# - **Cross-Validation**: This technique helps assess model performance and generalization by dividing the data into subsets, training the model on some subsets while validating it on others.
#
# - **Evaluation Metrics**: To measure the effectiveness of machine learning models, various metrics are used, including accuracy, precision, recall, and F1 score.
#
# ### Summary
#
# Machine learning encompasses supervised, unsupervised, and reinforcement learning, utilizing algorithms like decision trees and neural networks. Key processes include data preprocessing, model training, and avoiding overfitting and underfitting. Cross-validation and evaluation metrics are essential for assessing model performance.
#
# For further reading, you can explore resources from:
# - [Coursera](https://www.coursera.org/learn/machine-learning)
# - [edX](https://www.edx.org/course/machine-learning-introduction)
# - [Kaggle](https://www.kaggle.com/learn/overview)
# - [IBM](https://www.ibm.com/cloud/learn/machine-learning)
# - [Towards Data Science](https://towardsdatascience.com/machine-learning-basics-101-1f1c1c1e1f3e)
# - [Analytics Vidhya](https://www.analyticsvidhya.com/blog/2020/10/understanding-machine-learning-algorithms/)
# - [GeeksforGeeks](https://www.geeksforgeeks.org/machine-learning-introduction/)
